# %%
# !pip install copernicusmarine
# Out:
# Collecting copernicusmarine
#   Using cached copernicusmarine-2.3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting arcosparse<0.5.0,>=0.4.2 (from copernicusmarine)
#   Using cached arcosparse-0.4.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting boto3>=1.26 (from copernicusmarine)
#   Downloading boto3-1.42.59-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: click!=8.2.0,<8.3.0,>=8.0.4 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (8.2.1)
# Requirement already satisfied: dask>=2022 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (2025.12.0)
# Collecting h5netcdf<2.0.0,>=1.4.0 (from copernicusmarine)
#   Using cached h5netcdf-1.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.23.0 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (2.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.1 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (2.12.4)
# Collecting pystac>=1.8.3 (from copernicusmarine)
#   Using cached pystac-1.14.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: requests>=2.27.1 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (2.32.5)
# Requirement already satisfied: semver>=3.0.2 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (3.0.4)
# Requirement already satisfied: setuptools>=68.2.2 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (80.10.2)
# Requirement already satisfied: tqdm>=4.65.0 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (4.67.3)
# Requirement already satisfied: xarray>=2023.4.0 in C:\ProgramData\anaconda3\Lib\site-packages (from copernicusmarine) (2025.12.0)
# Collecting zarr>=2.13.3 (from copernicusmarine)
#   Using cached zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas<3,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from arcosparse<0.5.0,>=0.4.2->copernicusmarine) (2.3.3)
# Requirement already satisfied: pyarrow>=17.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from arcosparse<0.5.0,>=0.4.2->copernicusmarine) (21.0.0)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\Lib\site-packages (from click!=8.2.0,<8.3.0,>=8.0.4->copernicusmarine) (0.4.6)
# Requirement already satisfied: packaging in C:\ProgramData\anaconda3\Lib\site-packages (from h5netcdf<2.0.0,>=1.4.0->copernicusmarine) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas<3,>=2->arcosparse<0.5.0,>=0.4.2->copernicusmarine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas<3,>=2->arcosparse<0.5.0,>=0.4.2->copernicusmarine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas<3,>=2->arcosparse<0.5.0,>=0.4.2->copernicusmarine) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\ProgramData\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.27.1->copernicusmarine) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.27.1->copernicusmarine) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.27.1->copernicusmarine) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.27.1->copernicusmarine) (2026.1.4)
# Collecting botocore<1.43.0,>=1.42.59 (from boto3>=1.26->copernicusmarine)
#   Downloading botocore-1.42.59-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in C:\ProgramData\anaconda3\Lib\site-packages (from boto3>=1.26->copernicusmarine) (1.1.0)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3>=1.26->copernicusmarine)
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: six>=1.5 in C:\ProgramData\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=2->arcosparse<0.5.0,>=0.4.2->copernicusmarine) (1.17.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in C:\ProgramData\anaconda3\Lib\site-packages (from dask>=2022->copernicusmarine) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in C:\ProgramData\anaconda3\Lib\site-packages (from dask>=2022->copernicusmarine) (2026.1.0)
# Requirement already satisfied: partd>=1.4.0 in C:\ProgramData\anaconda3\Lib\site-packages (from dask>=2022->copernicusmarine) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\ProgramData\anaconda3\Lib\site-packages (from dask>=2022->copernicusmarine) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in C:\ProgramData\anaconda3\Lib\site-packages (from dask>=2022->copernicusmarine) (1.1.0)
# Requirement already satisfied: locket in C:\ProgramData\anaconda3\Lib\site-packages (from partd>=1.4.0->dask>=2022->copernicusmarine) (1.0.0)
# Collecting donfig>=0.8 (from zarr>=2.13.3->copernicusmarine)
#   Using cached donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting google-crc32c>=1.5 (from zarr>=2.13.3->copernicusmarine)
#   Using cached google_crc32c-1.8.0-cp313-cp313-win_amd64.whl.metadata (1.8 kB)
# Collecting numcodecs>=0.14 (from zarr>=2.13.3->copernicusmarine)
#   Using cached numcodecs-0.16.5-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Using cached copernicusmarine-2.3.0-py3-none-any.whl (125 kB)
# Using cached arcosparse-0.4.2-py3-none-any.whl (26 kB)
# Using cached h5netcdf-1.8.1-py3-none-any.whl (62 kB)
# Using cached pystac-1.14.3-py3-none-any.whl (208 kB)
# Downloading boto3-1.42.59-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.59-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.6 MB 5.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.9/14.6 MB 11.1 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.6 MB 12.4 MB/s eta 0:00:01
#    --------------------------- ------------ 10.0/14.6 MB 12.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.8/14.6 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 7.0 MB/s  0:00:02
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Using cached zarr-3.1.5-py3-none-any.whl (284 kB)
# Using cached donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Using cached google_crc32c-1.8.0-cp313-cp313-win_amd64.whl (34 kB)
# Using cached numcodecs-0.16.5-cp313-cp313-win_amd64.whl (799 kB)
# Installing collected packages: numcodecs, h5netcdf, google-crc32c, donfig, zarr, pystac, botocore, s3transfer, arcosparse, boto3, copernicusmarine
#
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    ----------------------------------------  0/11 [numcodecs]
#    --- ------------------------------------  1/11 [h5netcdf]
#    --- ------------------------------------  1/11 [h5netcdf]
#    --- ------------------------------------  1/11 [h5netcdf]
#    --- ------------------------------------  1/11 [h5netcdf]
#    --- ------------------------------------  1/11 [h5netcdf]
#    --- ------------------------------------  1/11 [h5netcdf]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ------- --------------------------------  2/11 [google-crc32c]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    ---------- -----------------------------  3/11 [donfig]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    -------------- -------------------------  4/11 [zarr]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#    ------------------ ---------------------  5/11 [pystac]
#   Attempting uninstall: botocore
#    ------------------ ---------------------  5/11 [pystac]
#    --------------------- ------------------  6/11 [botocore]
#     Found existing installation: botocore 1.42.19
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#     Uninstalling botocore-1.42.19:
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#       Successfully uninstalled botocore-1.42.19
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    --------------------- ------------------  6/11 [botocore]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ------------------------- --------------  7/11 [s3transfer]
#    ----------------------------- ----------  8/11 [arcosparse]
#    ----------------------------- ----------  8/11 [arcosparse]
#    ----------------------------- ----------  8/11 [arcosparse]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    -------------------------------- -------  9/11 [boto3]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ---------------------------------------- 11/11 [copernicusmarine]
#
# Successfully installed arcosparse-0.4.2 boto3-1.42.59 botocore-1.42.59 copernicusmarine-2.3.0 donfig-0.8.1.post1 google-crc32c-1.8.0 h5netcdf-1.8.1 numcodecs-0.16.5 pystac-1.14.3 s3transfer-0.16.0 zarr-3.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 3.1.0 requires botocore<1.42.20,>=1.41.0, but you have botocore 1.42.59 which is incompatible.

# %%
import copernicusmarine

# %%
import os

# Get current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\dodhiak\OneDrive - Lancaster University\PhD\PhD\Reanalysis data set

# %%
copernicusmarine.subset(
  dataset_id="cmems_mod_ibi_phy-temp_my_0.027deg_PT1H-m",
  variables=["thetao"],
  minimum_longitude=-7,
  maximum_longitude=3,
  minimum_latitude=49,
  maximum_latitude=56,
  start_datetime="1993-01-01T23:00:00",
  end_datetime="2025-10-28T23:00:00"
)
# Out:
# INFO - 2026-03-02T13:38:16Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   kdodhia
# Copernicus Marine password:
#   ········
# INFO - 2026-03-02T13:38:33Z - Selected dataset version: "202511"
# INFO - 2026-03-02T13:38:33Z - Selected dataset part: "default"
#   0%|          | 0/5485 [00:00<?, ?it/s]
# ResponseSubset(file_path=WindowsPath('cmems_mod_ibi_phy-temp_my_0.027deg_PT1H-m_thetao_7.00W-2.97E_49.03N-56.00N_1993-01-01-2025-10-28.nc'), output_directory=WindowsPath('.'), filename='cmems_mod_ibi_phy-temp_my_0.027deg_PT1H-m_thetao_7.00W-2.97E_49.03N-56.00N_1993-01-01-2025-10-28.nc', file_size=99623.38460305345, data_transfer_size=116157.05697709923, variables=['thetao'], coordinates_extent=[GeographicalExtent(minimum=-6.999136924743652, maximum=2.973391056060791, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=49.02716827392578, maximum=55.99960708618164, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1993-01-01T23:00:00+00:00', maximum='2025-10-28T23:00:00+00:00', unit='iso8601', coordinate_id='time')], status='000', message='The request was successful.', file_status='DOWNLOADED')
